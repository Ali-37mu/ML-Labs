# %% [markdown]
# # K Nearest Neighbors Project
#
# Welcome to the KNN Project! This is a classified dataset from a company attempting to predict whether a customer belongs to **TARGET CLASS 0** or **TARGET CLASS 1** based on various anonymized features (WTT, PTI, EQW, etc.).
#
# We'll go through the full supervised ML workflow: EDA → Standardization → Model Training → Evaluation → Choosing the best K.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# Set the dataframe to the KNN_Project_Data file.

# %%
df = pd.read_csv('KNN_Project_Data')

# %% [markdown]
# **Check the head of the dataframe.**

# %%
df.head()

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Since the data is anonymized, we'll focus on visualizing the relationships between features using a pairplot.

# %% [markdown]
# **Create a pairplot with the hue indicated by the TARGET CLASS column.**

# %%
sns.pairplot(df, hue='TARGET CLASS', palette='coolwarm')

# %% [markdown]
# ## Standardize the Variables
#
# KNN is a distance-based algorithm, so it is very important to standardize the features so they all have a mean of 0 and a standard deviation of 1.

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Create a StandardScaler() object called scaler.**

# %%
scaler = StandardScaler()

# %% [markdown]
# **Fit scaler to the features.**

# %%
scaler.fit(df.drop('TARGET CLASS', axis=1))

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %%
scaled_features = scaler.transform(df.drop('TARGET CLASS', axis=1))

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
df_feat = pd.DataFrame(scaled_features, columns=df.columns[:-1])
df_feat.head()

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Use train_test_split to split your data into a training set and a testing set.**

# %%
X_train, X_test, y_train, y_test = train_test_split(df_feat, df['TARGET CLASS'],
                                                    test_size=0.30, random_state=101)

# %% [markdown]
# ## Using KNN
#
# **Import KNeighborsClassifier from scikit-learn.**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Create a KNN model instance with n_neighbors=1.**

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# **Fit this KNN model to the training data.**

# %%
knn.fit(X_train, y_train)

# %% [markdown]
# ## Predictions and Evaluations
#
# **Use the predict method to predict values using your KNN model and X_test.**

# %%
pred = knn.predict(X_test)

# %% [markdown]
# **Create a confusion matrix and classification report.**

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, pred))

# %%
print(classification_report(y_test, pred))

# %% [markdown]
# ## Choosing a K Value
#
# Let's go through the Elbow Method to pick a good K value.
#
# **Create a for loop that trains various KNN models with different k values, then keep track of the error_rate for each of these models with a list.**

# %%
error_rate = []

# will take some time
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %% [markdown]
# **Now create the following plot using the information from your for loop.**

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, 40), error_rate, color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')

# %% [markdown]
# ## Retrain with best K
#
# **Retrain your model with the best K value (where the error rate is lowest) and re-do the classification report and the confusion matrix.**

# %%
# NOW WITH K=5
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)
pred = knn.predict(X_test)

print('WITH K=5')
print('\n')
print(confusion_matrix(y_test, pred))
print('\n')
print(classification_report(y_test, pred))

# %% [markdown]
# ## Great Job!
#
# The model improved from **83% accuracy** with K=1 to **89% accuracy** with K=5. The elbow method helped us identify K=5 as a good value that minimizes the error rate while avoiding overfitting.
